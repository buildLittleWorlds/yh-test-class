# %% [markdown]
# # Weeks 10-12: Showcase Phase
# ## Share What You've Built
#
# **Duration:** 3 weeks (6 hours of class time)
#
# This is the final phase! You'll:
# - Week 10: Final polish, create demo, practice presentation
# - Week 11: First round of presentations + feedback
# - Week 12: Final presentations + reflection
#
# ---

# %% [markdown]
# ---
#
# # Week 10: Final Polish & Demo Prep
#
# ## Pre-Flight Checklist
#
# Before you present, make sure everything is solid.
#
# ### Technical Checklist
#
# - [ ] **All cells run without errors** (Restart and Run All)
# - [ ] **Models load successfully**
# - [ ] **Demo examples work every time**
# - [ ] **Edge cases handled** (empty input, weird characters, etc.)
# - [ ] **Output is clear and readable**
#
# ### Documentation Checklist
#
# - [ ] **Code has comments** explaining what each section does
# - [ ] **Function has docstring** explaining inputs/outputs
# - [ ] **README is complete** on GitHub
# - [ ] **Notebook has markdown sections** explaining the project
#
# ### Presentation Checklist
#
# - [ ] **Have 3 demo examples** ready (easy, interesting, challenging)
# - [ ] **Know what to say** for each part
# - [ ] **Timed presentation** (~5 minutes)
# - [ ] **Backup plan** if something doesn't work

# %% [markdown]
# ## Creating a Demo Script
#
# Write out exactly what you'll show and say.
#
# ### My Demo Script
#
# ---
#
# **[0:00-0:30] Introduction**
#
# "Hi, I'm [name], and my project is called [name]."
#
# "It helps [who] to [do what]."
#
# "The problem I'm solving is [problem]."
#
# ---
#
# **[0:30-1:30] Demo Example 1: Simple Case**
#
# "Let me show you a simple example."
#
# Input I'll use:
#
# What I'll point out:
#
# ---
#
# **[1:30-2:30] Demo Example 2: Interesting Case**
#
# "Now let's try something more interesting."
#
# Input I'll use:
#
# What I'll point out:
#
# ---
#
# **[2:30-3:30] Demo Example 3: Showing the AI's Limits**
#
# "Let me show you what happens when [tricky case]."
#
# Input I'll use:
#
# What I'll point out:
#
# ---
#
# **[3:30-4:30] How It Works**
#
# "Under the hood, this uses [X] AI models."
#
# "The [model 1] does [this], and then [model 2] does [that]."
#
# ---
#
# **[4:30-5:00] Reflection & Close**
#
# "The hardest part was [challenge]."
#
# "If I had more time, I would add [feature]."
#
# "Any questions?"
#
# ---

# %% [markdown]
# ## Demo Examples Cell
#
# Set up your demo examples so they're ready to run:

# %%
# DEMO SETUP - Run this before presenting!
# This cell loads your models and sets up examples

print("Loading models...")

# Your model loading code here
# ...

print("Models ready!")
print("\n" + "="*50)
print("DEMO READY TO START")
print("="*50)

# %%
# DEMO 1: Simple Example
print("DEMO 1: [Title]")
print("="*50)

demo1_input = ""  # Your demo input

# Your function call
# result = my_project(demo1_input)

# %%
# DEMO 2: Interesting Example
print("DEMO 2: [Title]")
print("="*50)

demo2_input = ""  # Your demo input

# Your function call
# result = my_project(demo2_input)

# %%
# DEMO 3: Edge Case / Interesting Limitation
print("DEMO 3: [Title]")
print("="*50)

demo3_input = ""  # Your demo input

# Your function call
# result = my_project(demo3_input)

# %% [markdown]
# ## Practice Run
#
# Do a full practice run:
# 1. Time yourself
# 2. Run through all demos
# 3. Practice what you'll say
#
# **Practice run time:** ___ minutes
#
# **What to adjust:**
#
# ---

# %% [markdown]
# ---
#
# # Week 11: Presentations Round 1
#
# ## Presentation Order
#
# | Order | Name | Project |
# |-------|------|----------|
# | 1 | | |
# | 2 | | |
# | 3 | | |
# | 4 | | |
# | 5 | | |
#
# ## Giving Feedback
#
# As you watch others present, take notes on:
# 1. What did they do well?
# 2. What was clever or creative?
# 3. What question do you have about their project?
#
# ### Feedback Notes
#
# **Presenter 1:**
# - Project:
# - What I liked:
# - Question I have:
#
# **Presenter 2:**
# - Project:
# - What I liked:
# - Question I have:
#
# **Presenter 3:**
# - Project:
# - What I liked:
# - Question I have:
#
# **Presenter 4:**
# - Project:
# - What I liked:
# - Question I have:
#
# **Presenter 5:**
# - Project:
# - What I liked:
# - Question I have:

# %% [markdown]
# ## Feedback I Received
#
# After your presentation, record the feedback:
#
# **What people liked:**
#
# **Questions asked:**
#
# **Suggestions for improvement:**
#
# **Changes I'll make for next week:**
#
# ---

# %% [markdown]
# ---
#
# # Week 12: Final Presentations & Reflection
#
# ## Final Presentation Improvements
#
# Based on Week 11 feedback, I improved:
# 1.
# 2.
# 3.

# %%
# FINAL DEMO - Updated based on feedback

# %% [markdown]
# ## Course Reflection
#
# Take time to reflect on your entire journey.
#
# ### What I Built
#
# **My final project:**
#
# **What it does:**
#
# **I'm most proud of:**
#
# ### Skills I Developed
#
# Rate yourself (1 = beginner, 5 = confident):
#
# | Skill | Week 1 | Now |
# |-------|--------|-----|
# | Using AI tools (HuggingFace Spaces, etc.) | | |
# | Running code in Google Colab | | |
# | Using AI to help write code | | |
# | Understanding what AI code does | | |
# | Combining multiple AI models | | |
# | Debugging when things don't work | | |
# | Explaining technical concepts | | |
# | Using GitHub | | |
#
# ### Key Learnings
#
# **The most important thing I learned about AI:**
#
# **The most surprising thing I learned:**
#
# **The most challenging part was:**
#
# **I overcame challenges by:**
#
# ### Looking Forward
#
# **I want to learn more about:**
#
# **A project I'd like to build next:**
#
# **How I might use AI in the future:**

# %% [markdown]
# ## Final Portfolio Summary
#
# ### My GitHub Portfolio
#
# **Repository URL:**
#
# **What's in my repo:**
# - [ ] Week 1 exploration notes
# - [ ] Week 2-3 experiments
# - [ ] Track-specific work (weeks 4-6)
# - [ ] Final project notebook
# - [ ] README describing my learning journey
#
# ### Project Summary for Portfolio/Applications
#
# Use this description when talking about your project:
#
# ```
# Project: [Name]
#
# I built [what it does] using [AI technologies]. The project [solves what problem / enables what capability] for [who].
#
# Technical highlights:
# - Used [model/technique 1] to [do what]
# - Combined [X] with [Y] to [achieve what]
# - Learned [key skill]
#
# This project taught me [biggest learning about AI/coding/problem-solving].
# ```

# %% [markdown]
# ## What's Next?
#
# ### Continue Learning
#
# **Free resources to explore:**
# - [Hugging Face Course](https://huggingface.co/learn) - Free NLP course
# - [fast.ai](https://www.fast.ai/) - Practical deep learning
# - [Kaggle Learn](https://www.kaggle.com/learn) - Data science tutorials
# - [Google AI](https://ai.google/education/) - Various AI resources
#
# **Ideas for your next project:**
# - Improve your current project with more features
# - Build a web interface (using Gradio or Streamlit)
# - Try a completely new AI task
# - Collaborate with a classmate on something bigger
#
# ### Stay Connected
#
# - Keep your GitHub active
# - Share what you build on your Hugging Face profile
# - Join AI communities online (Discord servers, Reddit, etc.)
#
# ---

# %% [markdown]
# ## Congratulations!
#
# You've completed the Youth Horizons AI Researcher Program - Level 2!
#
# You've learned to:
# - Explore and evaluate AI tools
# - Run AI models with code
# - Use AI assistants to help you code
# - Build your own AI-powered tools
# - Present technical work to others
#
# These skills will serve you well whether you continue in AI, pursue other tech interests, or use AI as a tool in any field.
#
# **Keep building. Keep learning. Keep asking questions.**
#
# ---
#
# *Youth Horizons AI Researcher Program - Level 2 | Showcase Phase*
#
# *Instructor: Dr. Daniel Plate*
